# %%
# %pip install opencv-python-headless
# %pip install seaborn
# %pip install matplotlib
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python-headless in /Users/ame/Library/Python/3.9/lib/python/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from opencv-python-headless) (2.0.2)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /Users/ame/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.2 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/ame/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: numpy>=1.23 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: pillow>=8 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: packaging>=20.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/ame/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/ame/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (2.0.2)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix, roc_curve, auc, precision_recall_fscore_support, matthews_corrcoef, cohen_kappa_score, balanced_accuracy_score, jaccard_score, log_loss, fbeta_score
)

batch_size = 2
learning_rate = 0.0001
group_type = "IssueTooth"
model_name = "Xception"
baseDir = "./dataset/"
os.listdir(baseDir)
# Out:
# ['test', 'train', 'dev']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_curve, auc, RocCurveDisplay,
    precision_recall_fscore_support, matthews_corrcoef, cohen_kappa_score,
    balanced_accuracy_score, jaccard_score, log_loss, top_k_accuracy_score
)
from sklearn.preprocessing import label_binarize

# -------------------------
# Training curves (works for any class count)
# -------------------------
def save_training_metrics(history, results_dir):
    os.makedirs(results_dir, exist_ok=True)

    # Accuracy
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.savefig(os.path.join(results_dir, "training_accuracy.png"))
    plt.close()

    # Loss
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.savefig(os.path.join(results_dir, "training_loss.png"))
    plt.close()

    # Text dump
    with open(os.path.join(results_dir, "training_validation_metrics.txt"), "w") as f:
        f.write("Training and Validation Metrics Per Epoch\n")
        f.write("=" * 50 + "\n")
        epochs = len(history.history['loss'])
        for i in range(epochs):
            acc = history.history['accuracy'][i]
            loss = history.history['loss'][i]
            val_acc = history.history.get('val_accuracy', [np.nan]*epochs)[i]
            val_loss = history.history.get('val_loss', [np.nan]*epochs)[i]
            f.write(f"Epoch {i+1}:\n")
            f.write(f"  Training Accuracy: {acc:.4f}, Validation Accuracy: {val_acc:.4f}\n")
            f.write(f"  Training Loss: {loss:.4f}, Validation Loss: {val_loss:.4f}\n")
            f.write("-" * 50 + "\n")

# -------------------------
# Confusion matrix (with optional normalization)
# -------------------------
def save_confusion_matrix(y_true, y_pred, class_names, results_dir, normalize=False):
    cm = confusion_matrix(y_true, y_pred, labels=range(len(class_names)))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1, keepdims=True).clip(min=1e-12)

    plt.figure(figsize=(8, 6))
    fmt = ".2f" if normalize else "d"
    sns.heatmap(cm, annot=True, fmt=fmt, cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix' + (' (Normalized)' if normalize else ''))
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, "confusion_matrix.png" if not normalize else "confusion_matrix_normalized.png"))
    plt.close()

# -------------------------
# ROC (one-vs-rest) for multiclass; binary handled as a special case
# -------------------------
def save_roc_curves(y_true, y_probs, class_names, results_dir):
    os.makedirs(results_dir, exist_ok=True)
    n_classes = len(class_names)

    # Binary case: standard single ROC
    if n_classes == 2:
        fpr, tpr, _ = roc_curve(y_true, y_probs[:, 1])
        roc_auc = auc(fpr, tpr)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr, tpr, lw=2, label=f"ROC (AUC = {roc_auc:.3f})")
        plt.plot([0, 1], [0, 1], lw=2, linestyle='--')
        plt.title('ROC Curve (Binary)')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.tight_layout()
        plt.savefig(os.path.join(results_dir, "roc_curve.png"))
        plt.close()
        return

    # Multiclass: OVR curves + micro/macro AUC
    y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))  # shape (N, C)

    # Compute per-class ROC + AUC
    fpr_dict, tpr_dict, auc_dict = {}, {}, {}
    for i in range(n_classes):
        fpr_dict[i], tpr_dict[i], _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
        auc_dict[i] = auc(fpr_dict[i], tpr_dict[i])

    # Micro-average
    fpr_dict["micro"], tpr_dict["micro"], _ = roc_curve(y_true_bin.ravel(), y_probs.ravel())
    auc_dict["micro"] = auc(fpr_dict["micro"], tpr_dict["micro"])

    # Macro-average
    # Average the AUCs directly (simple macro-AUC)
    auc_macro = np.mean([auc_dict[i] for i in range(n_classes)])
    auc_dict["macro"] = auc_macro

    # Plot all
    plt.figure(figsize=(10, 8))
    # Micro
    plt.plot(fpr_dict["micro"], tpr_dict["micro"], lw=3,
             label=f"micro-average ROC (AUC = {auc_dict['micro']:.3f})")
    # Each class
    for i, name in enumerate(class_names):
        plt.plot(fpr_dict[i], tpr_dict[i], lw=1.5, label=f"{name} (AUC = {auc_dict[i]:.3f})")
    # Chance
    plt.plot([0, 1], [0, 1], linestyle='--')

    plt.title('ROC Curves (One-vs-Rest)')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right', ncol=2, fontsize=9)
    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, "roc_curves_multiclass.png"))
    plt.close()

# -------------------------
# Metrics (binary or multiclass)
# -------------------------
def _per_class_specificity(y_true, y_pred, n_classes):
    """
    Specificity for each class in multiclass (treat class i as positive, others as negative).
    Returns array of shape (n_classes,).
    """
    specs = []
    cm = confusion_matrix(y_true, y_pred, labels=list(range(n_classes)))
    for i in range(n_classes):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        fp = cm[:, i].sum() - tp
        tn = cm.sum() - (tp + fn + fp)
        spec = tn / (tn + fp) if (tn + fp) > 0 else np.nan
        specs.append(spec)
    return np.array(specs)

def save_classification_metrics(y_true, y_pred, y_probs, results_dir, class_names, topk=(2,3)):
    """
    y_true: (N,) integer labels
    y_pred: (N,) integer predictions
    y_probs: (N, C) probabilities for each class
    """
    os.makedirs(results_dir, exist_ok=True)
    n_classes = len(class_names)

    # Averages
    # macro = unweighted mean across classes; weighted = class-frequency weighted
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(y_true, y_pred, average='macro', zero_division=0)
    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)

    # Multiclass-capable metrics
    mcc = matthews_corrcoef(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    balanced_acc = balanced_accuracy_score(y_true, y_pred)
    jaccard_macro = jaccard_score(y_true, y_pred, average='macro', zero_division=0)
    jaccard_weighted = jaccard_score(y_true, y_pred, average='weighted', zero_division=0)
    logloss = log_loss(y_true, y_probs)

    # Top-k
    topk_scores = {}
    for k in topk:
        if y_probs.shape[1] >= k:
            topk_scores[f"top_{k}_accuracy"] = top_k_accuracy_score(y_true, y_probs, k=k)

    # Specificity (per class + macro)
    specs = _per_class_specificity(y_true, y_pred, n_classes)
    specificity_macro = np.nanmean(specs)

    # Classification report (per class)
    report = classification_report(y_true, y_pred, target_names=class_names, zero_division=0)

    # Save text
    with open(os.path.join(results_dir, "classification_metrics.txt"), "w") as f:
        f.write("=== Macro / Weighted Averages ===\n")
        f.write(f"Precision (macro):  {precision_macro:.4f}\n")
        f.write(f"Recall (macro):     {recall_macro:.4f}\n")
        f.write(f"F1-Score (macro):   {f1_macro:.4f}\n")
        f.write(f"Precision (weighted): {precision_weighted:.4f}\n")
        f.write(f"Recall (weighted):    {recall_weighted:.4f}\n")
        f.write(f"F1-Score (weighted):  {f1_weighted:.4f}\n")
        f.write(f"Balanced Accuracy:   {balanced_acc:.4f}\n")
        f.write(f"Specificity (macro): {specificity_macro:.4f}\n")
        f.write(f"Jaccard (macro):     {jaccard_macro:.4f}\n")
        f.write(f"Jaccard (weighted):  {jaccard_weighted:.4f}\n")
        f.write(f"MCC:                 {mcc:.4f}\n")
        f.write(f"Cohen's Kappa:       {kappa:.4f}\n")
        f.write(f"Log Loss:            {logloss:.4f}\n")
        for k, v in topk_scores.items():
            f.write(f"{k.replace('_',' ').title()}: {v:.4f}\n")
        f.write("\n=== Per-Class Specificity ===\n")
        for name, spec in zip(class_names, specs):
            f.write(f"{name}: {spec:.4f}\n")
        f.write("\n=== Classification Report ===\n")
        f.write(report)

# -------------------------
# Orchestrator
# -------------------------
def save_model_metrics(model, test_ds, results_dir, class_names):
    """
    - Evaluates the model
    - Collects y_true, y_probs, y_pred
    - Saves confusion matrix, ROC curves, metrics
    Works if test_ds yields (x, y) where y is one-hot or sparse ints.
    """
    os.makedirs(results_dir, exist_ok=True)
    print("Evaluating the model on test data...")
    test_loss, test_accuracy = model.evaluate(test_ds)
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    with open(os.path.join(results_dir, "testing_metrics.txt"), "w") as f:
        f.write(f"Test Loss: {test_loss:.4f}\n")
        f.write(f"Test Accuracy: {test_accuracy:.4f}\n")

    # Gather labels from dataset
    ys = []
    for _, y in test_ds:
        ys.append(y.numpy())
    y_true_raw = np.concatenate(ys, axis=0)

    # Handle one-hot vs sparse
    if y_true_raw.ndim == 2 and y_true_raw.shape[1] > 1:
        y_true = np.argmax(y_true_raw, axis=1)
    else:
        y_true = y_true_raw.squeeze().astype(int)

    # Predict probabilities
    y_probs = model.predict(test_ds)
    if y_probs.ndim == 1:  # binary model with a single sigmoid output
        y_probs = np.stack([1 - y_probs, y_probs], axis=1)

    # Predicted labels
    y_pred = np.argmax(y_probs, axis=1)

    # Confusion matrices
    save_confusion_matrix(y_true, y_pred, class_names, results_dir, normalize=False)
    save_confusion_matrix(y_true, y_pred, class_names, results_dir, normalize=True)

    # ROC curves (binary or multiclass automatically)
    save_roc_curves(y_true, y_probs, class_names, results_dir)

    # Metrics (binary or multiclass automatically)
    save_classification_metrics(y_true, y_pred, y_probs, results_dir, class_names)

# %%
# ANOVA requires that you don't have a seed.

def get_images_and_classes():
    # Load training and validation datasets

    train_ds = tf.keras.utils.image_dataset_from_directory(
        baseDir + "train",
        labels="inferred",
        label_mode="categorical",  # Use categorical for multi-class classification
        image_size=(224, 224),
        batch_size=batch_size,
        shuffle=True,
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        baseDir + "dev",
        labels="inferred",
        label_mode="categorical",
        image_size=(224, 224),
        batch_size=batch_size,
        shuffle=True,
    )

    # Test dataset (assuming separate directory for test data)
    test_ds = tf.keras.utils.image_dataset_from_directory(
        baseDir + "test",
        labels="inferred",
        label_mode="categorical",
        image_size=(224, 224),
        batch_size=batch_size,
        shuffle=False  # No shuffling for test set
    )

    class_names = train_ds.class_names

    for images, labels in train_ds.take(1):
        print(f"Images shape: {images.shape}")
        print(f"Labels shape: {labels.shape}")
    
    return (train_ds, val_ds, test_ds, class_names)

# %% [markdown]
# ### Dataset normalization

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomContrast(factor=0.2),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomRotation(0.1)
]) # Light Augmentation

def augment_and_normalize(_train_ds, _val_ds, _test_ds):
    internal_train_ds = _train_ds.map(lambda x, y: (normalization_layer(data_augmentation(x, training=True)), y))
    internal_val_ds = _val_ds.map(lambda x, y: (normalization_layer(x), y))
    internal_test_ds = _test_ds.map(lambda x, y: (normalization_layer(x), y))

    AUTOTUNE = tf.data.AUTOTUNE
    output_train_ds = internal_train_ds.prefetch(buffer_size=AUTOTUNE)
    output_val_ds = internal_val_ds.prefetch(buffer_size=AUTOTUNE)
    output_test_ds = internal_test_ds.prefetch(buffer_size=AUTOTUNE)
    
    return (output_train_ds, output_val_ds, output_test_ds)

# %% [markdown]
# ### Load ResNet50V2 architecture

# %%
def create_and_compile_model():
    Xception = tf.keras.applications.Xception(input_shape = (224,224,3), include_top=False)

    model = Sequential([
        tf.keras.Input(shape=(224, 224, 3)),  # 🔹 Explicit input layer
        Xception,
        # 🌀 Replace Flatten with GlobalAveragePooling2D for better generalization
        GlobalAveragePooling2D(),

        # 🧩 Add normalization and dropout for stability
        BatchNormalization(),
        Dense(512, activation='relu'),
        Dropout(0.5),

        Dense(256, activation='relu'),
        Dropout(0.3),
        Dense(4, activation='softmax')  # Final classification layer
    ])

    # Call model to initialize input shape
    model.build(input_shape=(None, 224, 224, 3))

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',  # Suitable for binary classification
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Train model

# %%
import os

ANOVA_REPEATS = 5
epochs = 35

for index in range(1, ANOVA_REPEATS + 1):
    print("REPEAT ROUND: ", index)

    (train_ds, val_ds, test_ds, class_names) = get_images_and_classes()
    (output_train_ds, output_val_ds, output_test_ds) = augment_and_normalize(train_ds, val_ds, test_ds)
    model = create_and_compile_model()

    history = model.fit(output_train_ds, epochs=epochs, validation_data=output_val_ds)

    path = "results/" + group_type + "/" + model_name +"/"
    name = group_type.upper() + "_" + model_name +"_Round" + str(index) # Rounds are retrains for ANOVA

    # Ensure the results directory exists
    results_dir = path + name + "/"
    os.makedirs(results_dir, exist_ok=True)
    model.save(results_dir + name + ".keras")

    save_training_metrics(history, results_dir)
    save_model_metrics(model, output_test_ds, results_dir, class_names=class_names)
# Out:
# REPEAT ROUND:  1
# Found 285 files belonging to 4 classes.
# Found 118 files belonging to 4 classes.
# Found 76 files belonging to 4 classes.
# Images shape: (2, 224, 224, 3)
# Labels shape: (2, 4)
# Epoch 1/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2305s 16s/step - accuracy: 0.5180 - loss: 1.4708 - val_accuracy: 0.5932 - val_loss: 1.1640
# Epoch 2/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3083s 22s/step - accuracy: 0.5379 - loss: 1.2214 - val_accuracy: 0.5424 - val_loss: 1.0909
# Epoch 3/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.5562 - loss: 1.1587 - val_accuracy: 0.6186 - val_loss: 1.0761
# Epoch 4/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.5538 - loss: 1.0957 - val_accuracy: 0.6186 - val_loss: 1.5564
# Epoch 5/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 919ms/step - accuracy: 0.5629 - loss: 1.0203 - val_accuracy: 0.6441 - val_loss: 4.1528
# Epoch 6/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.5643 - loss: 1.0332 - val_accuracy: 0.6017 - val_loss: 3.8170
# Epoch 7/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5686 - loss: 1.0934 - val_accuracy: 0.6186 - val_loss: 4.8773
# Epoch 8/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 138s 964ms/step - accuracy: 0.5779 - loss: 1.0732 - val_accuracy: 0.5932 - val_loss: 3.6995
# Epoch 9/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 49150s 346s/step - accuracy: 0.6095 - loss: 1.0003 - val_accuracy: 0.6441 - val_loss: 2.8541
# Epoch 10/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.5603 - loss: 1.0236 - val_accuracy: 0.6356 - val_loss: 6.2356
# Epoch 11/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.5577 - loss: 1.0451 - val_accuracy: 0.6780 - val_loss: 5.3823
# Epoch 12/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.5753 - loss: 1.0116 - val_accuracy: 0.5169 - val_loss: 22.4269
# Epoch 13/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 141s 989ms/step - accuracy: 0.5619 - loss: 1.0006 - val_accuracy: 0.6441 - val_loss: 11.4195
# Epoch 14/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.5693 - loss: 1.0015 - val_accuracy: 0.6356 - val_loss: 10.2834
# Epoch 15/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.6026 - loss: 1.0489 - val_accuracy: 0.6186 - val_loss: 17.4102
# Epoch 16/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.5778 - loss: 0.9887 - val_accuracy: 0.6271 - val_loss: 14.8138
# Epoch 17/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.6315 - loss: 0.8990 - val_accuracy: 0.6864 - val_loss: 17.2784
# Epoch 18/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.5879 - loss: 0.9297 - val_accuracy: 0.7119 - val_loss: 12.3288
# Epoch 19/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6014 - loss: 0.9035 - val_accuracy: 0.6610 - val_loss: 21.7530
# Epoch 20/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.6197 - loss: 0.8784 - val_accuracy: 0.5085 - val_loss: 24.0021
# Epoch 21/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.6033 - loss: 0.8918 - val_accuracy: 0.5424 - val_loss: 22.3497
# Epoch 22/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.6399 - loss: 0.8539 - val_accuracy: 0.6864 - val_loss: 13.5226
# Epoch 23/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.6121 - loss: 0.8438 - val_accuracy: 0.6271 - val_loss: 35.5544
# Epoch 24/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.5734 - loss: 0.9410 - val_accuracy: 0.6695 - val_loss: 33.1985
# Epoch 25/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.6506 - loss: 0.8398 - val_accuracy: 0.6695 - val_loss: 41.5642
# Epoch 26/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.6248 - loss: 0.8922 - val_accuracy: 0.6949 - val_loss: 20.3266
# Epoch 27/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 129s 902ms/step - accuracy: 0.6234 - loss: 0.8642 - val_accuracy: 0.6864 - val_loss: 19.6487
# Epoch 28/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.6127 - loss: 0.9199 - val_accuracy: 0.6949 - val_loss: 27.8586
# Epoch 29/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.6691 - loss: 0.7933 - val_accuracy: 0.6949 - val_loss: 31.4807
# Epoch 30/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.6738 - loss: 0.8629 - val_accuracy: 0.6441 - val_loss: 41.1714
# Epoch 31/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.6345 - loss: 0.7582 - val_accuracy: 0.6695 - val_loss: 50.9592
# Epoch 32/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.6719 - loss: 0.7302 - val_accuracy: 0.7034 - val_loss: 42.5213
# Epoch 33/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.6377 - loss: 0.8214 - val_accuracy: 0.6610 - val_loss: 60.6312
# Epoch 34/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.5657 - loss: 0.9141 - val_accuracy: 0.6102 - val_loss: 25.9985
# Epoch 35/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6400 - loss: 0.8378 - val_accuracy: 0.6610 - val_loss: 29.3588
# Evaluating the model on test data...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 190ms/step - accuracy: 0.2442 - loss: 51.4104
# Test Loss: 42.6223
# Test Accuracy: 0.5921
# 2026-01-09 09:41:13.754128: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 283ms/step
# REPEAT ROUND:  2
# Found 285 files belonging to 4 classes.
# Found 118 files belonging to 4 classes.
# Found 76 files belonging to 4 classes.
# Images shape: (2, 224, 224, 3)
# Labels shape: (2, 4)
# Epoch 1/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.3759 - loss: 1.5848 - val_accuracy: 0.6102 - val_loss: 1.1494
# Epoch 2/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.5173 - loss: 1.3831 - val_accuracy: 0.6186 - val_loss: 1.0327
# Epoch 3/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.5569 - loss: 1.2926 - val_accuracy: 0.6186 - val_loss: 1.1437
# Epoch 4/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.5476 - loss: 1.1170 - val_accuracy: 0.6186 - val_loss: 2.2133
# Epoch 5/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.6036 - loss: 0.9864 - val_accuracy: 0.6186 - val_loss: 5.3114
# Epoch 6/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6042 - loss: 1.0360 - val_accuracy: 0.6186 - val_loss: 3.7206
# Epoch 7/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.6120 - loss: 0.9769 - val_accuracy: 0.6186 - val_loss: 7.3497
# Epoch 8/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.6258 - loss: 0.9180 - val_accuracy: 0.6186 - val_loss: 7.4080
# Epoch 9/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 142s 993ms/step - accuracy: 0.6042 - loss: 0.9134 - val_accuracy: 0.6186 - val_loss: 7.1046
# Epoch 10/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.5906 - loss: 0.9626 - val_accuracy: 0.6271 - val_loss: 11.2686
# Epoch 11/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.6434 - loss: 0.8724 - val_accuracy: 0.6441 - val_loss: 7.8903
# Epoch 12/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.6209 - loss: 0.9288 - val_accuracy: 0.6271 - val_loss: 4.4999
# Epoch 13/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6547 - loss: 0.9076 - val_accuracy: 0.6186 - val_loss: 2.7658
# Epoch 14/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 138s 967ms/step - accuracy: 0.5836 - loss: 0.9056 - val_accuracy: 0.6525 - val_loss: 1.8233
# Epoch 15/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 927ms/step - accuracy: 0.6007 - loss: 0.9238 - val_accuracy: 0.6525 - val_loss: 1.7531
# Epoch 16/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 931ms/step - accuracy: 0.6156 - loss: 0.8875 - val_accuracy: 0.6780 - val_loss: 1.5317
# Epoch 17/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 141s 988ms/step - accuracy: 0.6214 - loss: 0.8746 - val_accuracy: 0.6441 - val_loss: 1.4519
# Epoch 18/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.6045 - loss: 0.9070 - val_accuracy: 0.6695 - val_loss: 2.2509
# Epoch 19/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.6497 - loss: 0.8763 - val_accuracy: 0.6949 - val_loss: 2.4120
# Epoch 20/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 980ms/step - accuracy: 0.6576 - loss: 0.8847 - val_accuracy: 0.6695 - val_loss: 1.6144
# Epoch 21/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.6432 - loss: 0.8658 - val_accuracy: 0.7034 - val_loss: 1.4221
# Epoch 22/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 139s 972ms/step - accuracy: 0.6748 - loss: 0.8043 - val_accuracy: 0.7288 - val_loss: 1.9113
# Epoch 23/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.6115 - loss: 0.9258 - val_accuracy: 0.6780 - val_loss: 2.3043
# Epoch 24/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6421 - loss: 0.8529 - val_accuracy: 0.7034 - val_loss: 3.0282
# Epoch 25/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.6402 - loss: 0.8173 - val_accuracy: 0.6271 - val_loss: 2.9079
# Epoch 26/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.6511 - loss: 0.8464 - val_accuracy: 0.5593 - val_loss: 4.5141
# Epoch 27/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.6211 - loss: 0.8136 - val_accuracy: 0.6525 - val_loss: 4.3222
# Epoch 28/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6478 - loss: 0.8638 - val_accuracy: 0.5932 - val_loss: 4.5847
# Epoch 29/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 221s 2s/step - accuracy: 0.6518 - loss: 0.8258 - val_accuracy: 0.5593 - val_loss: 5.1582
# Epoch 30/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 142s 992ms/step - accuracy: 0.6686 - loss: 0.8003 - val_accuracy: 0.6441 - val_loss: 3.4828
# Epoch 31/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.6336 - loss: 0.8910 - val_accuracy: 0.6525 - val_loss: 4.9765
# Epoch 32/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.6887 - loss: 0.7048 - val_accuracy: 0.6186 - val_loss: 6.0504
# Epoch 33/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.6950 - loss: 0.7474 - val_accuracy: 0.6949 - val_loss: 7.0727
# Epoch 34/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 137s 955ms/step - accuracy: 0.6982 - loss: 0.7198 - val_accuracy: 0.5254 - val_loss: 6.1419
# Epoch 35/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.7032 - loss: 0.6982 - val_accuracy: 0.6525 - val_loss: 7.7266
# Evaluating the model on test data...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 207ms/step - accuracy: 0.3000 - loss: 12.8303
# Test Loss: 10.8942
# Test Accuracy: 0.5395
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step
# REPEAT ROUND:  3
# Found 285 files belonging to 4 classes.
# Found 118 files belonging to 4 classes.
# Found 76 files belonging to 4 classes.
# Images shape: (2, 224, 224, 3)
# Labels shape: (2, 4)
# Epoch 1/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.3961 - loss: 1.4918 - val_accuracy: 0.6186 - val_loss: 1.0371
# Epoch 2/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.5865 - loss: 1.2682 - val_accuracy: 0.6186 - val_loss: 1.0333
# Epoch 3/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.5756 - loss: 1.0988 - val_accuracy: 0.6186 - val_loss: 0.9802
# Epoch 4/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.5799 - loss: 1.0303 - val_accuracy: 0.6186 - val_loss: 1.8933
# Epoch 5/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.6335 - loss: 1.0011 - val_accuracy: 0.6186 - val_loss: 2.9596
# Epoch 6/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6355 - loss: 0.9451 - val_accuracy: 0.6186 - val_loss: 8.8998
# Epoch 7/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.6264 - loss: 1.0571 - val_accuracy: 0.6186 - val_loss: 9.6705
# Epoch 8/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6220 - loss: 0.9943 - val_accuracy: 0.6271 - val_loss: 13.1116
# Epoch 9/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.6051 - loss: 0.9415 - val_accuracy: 0.6271 - val_loss: 7.5375
# Epoch 10/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.6042 - loss: 0.9986 - val_accuracy: 0.6356 - val_loss: 7.9699
# Epoch 11/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.6534 - loss: 0.9321 - val_accuracy: 0.6525 - val_loss: 3.5682
# Epoch 12/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6445 - loss: 0.9696 - val_accuracy: 0.6780 - val_loss: 4.4468
# Epoch 13/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.6349 - loss: 0.9521 - val_accuracy: 0.6864 - val_loss: 3.8252
# Epoch 14/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.6129 - loss: 0.9173 - val_accuracy: 0.6610 - val_loss: 5.6499
# Epoch 15/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.6277 - loss: 0.9421 - val_accuracy: 0.6271 - val_loss: 3.7140
# Epoch 16/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.6670 - loss: 0.9172 - val_accuracy: 0.6780 - val_loss: 3.1787
# Epoch 17/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.6589 - loss: 0.8831 - val_accuracy: 0.6610 - val_loss: 6.3476
# Epoch 18/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.6603 - loss: 0.8763 - val_accuracy: 0.6525 - val_loss: 4.5145
# Epoch 19/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.6351 - loss: 0.8613 - val_accuracy: 0.7203 - val_loss: 4.1786
# Epoch 20/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.6802 - loss: 0.8745 - val_accuracy: 0.6525 - val_loss: 6.3755
# Epoch 21/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.6817 - loss: 0.8617 - val_accuracy: 0.6695 - val_loss: 7.6824
# Epoch 22/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.7188 - loss: 0.8851 - val_accuracy: 0.6864 - val_loss: 10.1084
# Epoch 23/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.6179 - loss: 0.8879 - val_accuracy: 0.6780 - val_loss: 8.5289
# Epoch 24/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.7025 - loss: 0.7846 - val_accuracy: 0.7119 - val_loss: 10.1390
# Epoch 25/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.6617 - loss: 0.8449 - val_accuracy: 0.6864 - val_loss: 12.9310
# Epoch 26/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.6658 - loss: 0.8171 - val_accuracy: 0.6949 - val_loss: 8.1717
# Epoch 27/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1259s 7s/step - accuracy: 0.6626 - loss: 0.7852 - val_accuracy: 0.6695 - val_loss: 9.2791
# Epoch 28/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 922ms/step - accuracy: 0.6614 - loss: 0.8628 - val_accuracy: 0.4661 - val_loss: 15.6691
# Epoch 29/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 933ms/step - accuracy: 0.6672 - loss: 0.8413 - val_accuracy: 0.6610 - val_loss: 7.6114
# Epoch 30/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 947ms/step - accuracy: 0.7439 - loss: 0.7942 - val_accuracy: 0.6864 - val_loss: 5.0579
# Epoch 31/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 940ms/step - accuracy: 0.6921 - loss: 0.7923 - val_accuracy: 0.6525 - val_loss: 6.7866
# Epoch 32/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 137s 958ms/step - accuracy: 0.6703 - loss: 0.8133 - val_accuracy: 0.6780 - val_loss: 7.9950
# Epoch 33/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 137s 955ms/step - accuracy: 0.6945 - loss: 0.8098 - val_accuracy: 0.6525 - val_loss: 5.4467
# Epoch 34/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 930ms/step - accuracy: 0.6998 - loss: 0.8022 - val_accuracy: 0.6864 - val_loss: 8.5225
# Epoch 35/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 929ms/step - accuracy: 0.7199 - loss: 0.7633 - val_accuracy: 0.6695 - val_loss: 25.8402
# Evaluating the model on test data...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 228ms/step - accuracy: 0.3252 - loss: 36.4973
# Test Loss: 30.2280
# Test Accuracy: 0.6316
# 2026-01-09 13:07:46.066377: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 213ms/step
# REPEAT ROUND:  4
# Found 285 files belonging to 4 classes.
# Found 118 files belonging to 4 classes.
# Found 76 files belonging to 4 classes.
# Images shape: (2, 224, 224, 3)
# Labels shape: (2, 4)
# Epoch 1/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 159s 970ms/step - accuracy: 0.3827 - loss: 1.5546 - val_accuracy: 0.5678 - val_loss: 1.0723
# Epoch 2/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 135s 940ms/step - accuracy: 0.4935 - loss: 1.2636 - val_accuracy: 0.6186 - val_loss: 1.0330
# Epoch 3/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 937ms/step - accuracy: 0.5137 - loss: 1.1239 - val_accuracy: 0.6102 - val_loss: 0.9984
# Epoch 4/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 951ms/step - accuracy: 0.5354 - loss: 1.0930 - val_accuracy: 0.6102 - val_loss: 0.9714
# Epoch 5/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 138s 960ms/step - accuracy: 0.5742 - loss: 1.0842 - val_accuracy: 0.6356 - val_loss: 2.6206
# Epoch 6/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 949ms/step - accuracy: 0.6100 - loss: 0.9577 - val_accuracy: 0.6525 - val_loss: 0.9637
# Epoch 7/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 930ms/step - accuracy: 0.5891 - loss: 0.9372 - val_accuracy: 0.6186 - val_loss: 1.3616
# Epoch 8/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 950ms/step - accuracy: 0.5893 - loss: 1.0584 - val_accuracy: 0.6525 - val_loss: 1.3691
# Epoch 9/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.5819 - loss: 1.0042 - val_accuracy: 0.6356 - val_loss: 1.2753
# Epoch 10/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 925ms/step - accuracy: 0.5909 - loss: 1.0291 - val_accuracy: 0.5847 - val_loss: 1.3136
# Epoch 11/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 924ms/step - accuracy: 0.6340 - loss: 0.9360 - val_accuracy: 0.6525 - val_loss: 1.3265
# Epoch 12/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 929ms/step - accuracy: 0.5933 - loss: 0.9730 - val_accuracy: 0.6949 - val_loss: 1.3995
# Epoch 13/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 976ms/step - accuracy: 0.6000 - loss: 0.9638 - val_accuracy: 0.6356 - val_loss: 1.3131
# Epoch 14/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 137s 959ms/step - accuracy: 0.6260 - loss: 0.8886 - val_accuracy: 0.6356 - val_loss: 1.2296
# Epoch 15/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 135s 941ms/step - accuracy: 0.5546 - loss: 0.9936 - val_accuracy: 0.6610 - val_loss: 1.0761
# Epoch 16/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 952ms/step - accuracy: 0.6535 - loss: 0.8386 - val_accuracy: 0.6610 - val_loss: 1.5732
# Epoch 17/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 129s 903ms/step - accuracy: 0.5759 - loss: 0.9103 - val_accuracy: 0.6441 - val_loss: 2.0056
# Epoch 18/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 128s 897ms/step - accuracy: 0.6041 - loss: 0.9463 - val_accuracy: 0.6695 - val_loss: 1.6639
# Epoch 19/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 926ms/step - accuracy: 0.6282 - loss: 0.8349 - val_accuracy: 0.6695 - val_loss: 4.5690
# Epoch 20/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 937ms/step - accuracy: 0.6228 - loss: 0.9629 - val_accuracy: 0.6695 - val_loss: 3.4054
# Epoch 21/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 938ms/step - accuracy: 0.6685 - loss: 0.8788 - val_accuracy: 0.6780 - val_loss: 3.1550
# Epoch 22/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 137s 957ms/step - accuracy: 0.5853 - loss: 0.9087 - val_accuracy: 0.7119 - val_loss: 2.1098
# Epoch 23/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 135s 938ms/step - accuracy: 0.6820 - loss: 0.8093 - val_accuracy: 0.6864 - val_loss: 2.7832
# Epoch 24/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 124s 864ms/step - accuracy: 0.6807 - loss: 0.8203 - val_accuracy: 0.6441 - val_loss: 3.3692
# Epoch 25/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 128s 896ms/step - accuracy: 0.6121 - loss: 0.8622 - val_accuracy: 0.6102 - val_loss: 3.5631
# Epoch 26/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 920ms/step - accuracy: 0.6332 - loss: 0.8706 - val_accuracy: 0.6780 - val_loss: 3.0063
# Epoch 27/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 919ms/step - accuracy: 0.6837 - loss: 0.7669 - val_accuracy: 0.6949 - val_loss: 2.8593
# Epoch 28/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 978ms/step - accuracy: 0.6794 - loss: 0.7408 - val_accuracy: 0.6949 - val_loss: 6.1589
# Epoch 29/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 137s 953ms/step - accuracy: 0.6829 - loss: 0.8482 - val_accuracy: 0.7119 - val_loss: 5.4648
# Epoch 30/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 947ms/step - accuracy: 0.6930 - loss: 0.8026 - val_accuracy: 0.6780 - val_loss: 7.1817
# Epoch 31/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 135s 940ms/step - accuracy: 0.6279 - loss: 0.7992 - val_accuracy: 0.6610 - val_loss: 4.9920
# Epoch 32/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 939ms/step - accuracy: 0.6585 - loss: 0.8193 - val_accuracy: 0.6610 - val_loss: 4.2304
# Epoch 33/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 920ms/step - accuracy: 0.6589 - loss: 0.8382 - val_accuracy: 0.6780 - val_loss: 4.0291
# Epoch 34/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 131s 916ms/step - accuracy: 0.6712 - loss: 0.8673 - val_accuracy: 0.6780 - val_loss: 4.5187
# Epoch 35/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 933ms/step - accuracy: 0.7007 - loss: 0.7350 - val_accuracy: 0.6780 - val_loss: 3.0029
# Evaluating the model on test data...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - accuracy: 0.2992 - loss: 5.6969
# Test Loss: 4.5720
# Test Accuracy: 0.5526
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 225ms/step
# REPEAT ROUND:  5
# Found 285 files belonging to 4 classes.
# Found 118 files belonging to 4 classes.
# Found 76 files belonging to 4 classes.
# Images shape: (2, 224, 224, 3)
# Labels shape: (2, 4)
# Epoch 1/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 153s 934ms/step - accuracy: 0.2926 - loss: 1.8731 - val_accuracy: 0.6186 - val_loss: 1.1153
# Epoch 2/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 934ms/step - accuracy: 0.4463 - loss: 1.3608 - val_accuracy: 0.6017 - val_loss: 1.1114
# Epoch 3/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 929ms/step - accuracy: 0.5896 - loss: 1.1476 - val_accuracy: 0.6186 - val_loss: 1.1096
# Epoch 4/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 951ms/step - accuracy: 0.5175 - loss: 1.2118 - val_accuracy: 0.6186 - val_loss: 1.8142
# Epoch 5/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 927ms/step - accuracy: 0.4977 - loss: 1.1532 - val_accuracy: 0.6186 - val_loss: 3.6960
# Epoch 6/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 133s 929ms/step - accuracy: 0.5789 - loss: 1.0823 - val_accuracy: 0.6356 - val_loss: 2.5230
# Epoch 7/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 935ms/step - accuracy: 0.5375 - loss: 1.0395 - val_accuracy: 0.6186 - val_loss: 1.9585
# Epoch 8/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.5969 - loss: 1.0290 - val_accuracy: 0.6102 - val_loss: 2.1871
# Epoch 9/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.5992 - loss: 1.0267 - val_accuracy: 0.6186 - val_loss: 6.0549
# Epoch 10/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.5739 - loss: 1.0340 - val_accuracy: 0.6102 - val_loss: 1.8750
# Epoch 11/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.6128 - loss: 0.9823 - val_accuracy: 0.6102 - val_loss: 1.6837
# Epoch 12/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6385 - loss: 0.9134 - val_accuracy: 0.6441 - val_loss: 1.1439
# Epoch 13/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.6004 - loss: 0.9198 - val_accuracy: 0.6186 - val_loss: 1.4452
# Epoch 14/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 136s 949ms/step - accuracy: 0.5926 - loss: 1.0025 - val_accuracy: 0.6271 - val_loss: 1.6558
# Epoch 15/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 142s 993ms/step - accuracy: 0.6208 - loss: 0.9341 - val_accuracy: 0.6441 - val_loss: 1.2184
# Epoch 16/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.5571 - loss: 0.9578 - val_accuracy: 0.6441 - val_loss: 1.1369
# Epoch 17/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.6523 - loss: 0.9019 - val_accuracy: 0.6525 - val_loss: 2.0937
# Epoch 18/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 130s 907ms/step - accuracy: 0.6534 - loss: 0.8470 - val_accuracy: 0.6695 - val_loss: 2.0573
# Epoch 19/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.6461 - loss: 0.9269 - val_accuracy: 0.6949 - val_loss: 2.4739
# Epoch 20/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 982ms/step - accuracy: 0.6455 - loss: 0.9097 - val_accuracy: 0.6780 - val_loss: 2.0093
# Epoch 21/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.6670 - loss: 0.8475 - val_accuracy: 0.6610 - val_loss: 2.4123
# Epoch 22/35
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.6571 - loss: 0.9423 - val_accuracy: 0.6780 - val_loss: 2.4738
# Epoch 23/35
#   3/143 ━━━━━━━━━━━━━━━━━━━━ 6:41 3s/step - accuracy: 0.9444 - loss: 0.5823
